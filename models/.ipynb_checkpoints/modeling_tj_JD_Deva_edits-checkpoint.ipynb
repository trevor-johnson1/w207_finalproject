# %% [markdown]
# # House Prices - Advanced Regression Techniques
#
# ## Deva Kulkarni, Jared Dec, Marc Semonick, Trevor Johnson
#
# ## October 2021
#
# <br>
#
# Competition Link: https://www.kaggle.com/c/house-prices-advanced-regression-techniques
#
# Goal: Predict sales price for each house (`SalePrice`). RMSE on log(pred) - log(actual) will be the evaluation metric.
#
# Inference Problem:  Given known variables about a house, accurately predict its sale price.
#
# Deliverable: Final submission dataset should contain only the two fields `ID` and `SalePrice`.

# %% [markdown]
# # Setups

# %% [markdown]
# Import modules

# %%
# basics
import math
import os 

# data manipulation/viz
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# modeling
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.formula.api import glm 
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# linear modeling
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# tree modeling
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

#K-Fold cross-validation
from numpy import mean
from numpy import std
from numpy import absolute
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold

# scale the data
from sklearn.preprocessing import StandardScaler

# Ridge Regression
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet

# %% [markdown]
# Load in the data

# %%
# # optional directory set-up
# working_dir = !pwd
# train = pd.read_csv(os.path.join(working_dir[0], "../../housing_data", "train.csv"))
# test = pd.read_csv(os.path.join(working_dir[0], "../../housing_data", "test.csv"))
# sample = pd.read_csv(os.path.join(working_dir[0], "../../housing_data", "sample_submission.csv"))

# Load data (Specific to Deva)
test = pd.read_csv("../../housing_data/test.csv")
train = pd.read_csv("../../housing_data/train.csv")
sample = pd.read_csv("../../housing_data/sample_submission.csv")
print(test.shape)
print(train.shape)
# Out:
# (1459, 80)
# (1460, 81)

# %%
# Out:
# /c/Users/drkul/desktop/mids/w207/Final_Project/w207_finalproject/models

# %%
# train =pd.read_csv('C:/Users/19258/Downloads/house-prices-advanced-regression-techniques/train.csv')
# test = pd.read_csv("C:/Users/19258/Downloads/house-prices-advanced-regression-techniques/test.csv")
# sample = pd.read_csv("C:/Users/19258/Downloads/house-prices-advanced-regression-techniques/sample_submission.csv")

# print("train shape: {}".format(train.shape))
# print("test shape: {}".format(test.shape))

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# Deal with missing values

# %%
print("Count number of missing values per variable:")
print(train.isnull().sum()[train.isnull().sum() != 0])

# function to clean the missing values
def na_clean(df):
    
    # some vars are just too missing so I remove the field
    df = df.drop(columns = ["PoolQC", "MiscFeature"])

    # replace some numeric vars w/ median
    median_replace_vars = ['LotFrontage', 'MasVnrArea', 'GarageYrBlt', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'GarageArea']
    for var in median_replace_vars:
        df[var].fillna(df[var].median(), inplace = True)
    
    # replace some num vars w/ 0
    zero_replace_vars = ['BsmtFullBath', 'BsmtHalfBath', 'GarageCars']
    for var in zero_replace_vars:
        df[var].fillna(0, inplace = True)
    
    # replace some cat vars w/ most freq value 
    df['MasVnrType'].fillna('None', inplace = True)
    df['Electrical'].fillna('SBrkr', inplace = True)
    df['MSZoning'].fillna('RL', inplace = True)
    df['SaleType'].fillna('WD', inplace = True)
    df['Utilities'].fillna('AllPub', inplace = True)
    df['KitchenQual'].fillna('TA', inplace = True)
    df['Functional'].fillna('Typ', inplace = True)

    # other cat vars just put missing if there isn't a glaring most popular category
    replace_missing_vars = ['Alley', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 
        'BsmtFinType2', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'Fence', 'Exterior1st', 
        'Exterior2nd', 'FireplaceQu']
    for var in replace_missing_vars:
        df[var].fillna("Missing", inplace = True)

    return df

train = na_clean(train)
test = na_clean(test)

# make sure there are no more missing values
print("\nNumber of missing values after running na_clean()")
print("Missing values in train: {}".format(train.isnull().sum().sum()))
print("Missing values in test: {}".format(test.isnull().sum().sum()))
# Out:
# Count number of missing values per variable:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64
#
# Number of missing values after running na_clean()
# Missing values in train: 0
# Missing values in test: 0

# %% [markdown]
# ## Feature Engineering
#
# Simplifying the data for any future model we use

# %%
# keep adapting this formula to change how we feature engineer
def feature_eng(df, test_data = False):
    '''Input either the training or test data. 
    2nd arg set to True if it's the testing data. That way we ignore the final log transformation on sale price'''

    # num features to just binarize b/c few houses have the feature
    df["SwimmingPool"] = df['PoolArea'].map(lambda x: 0 if x==0 else 1)
    df["3SsnPorch"] = df['3SsnPorch'].map(lambda x: 0 if x==0 else 1)
    df["ScreenPorch"] = df['ScreenPorch'].map(lambda x: 0 if x==0 else 1)

    # re-factoring vars:
    # group the irregularities into 2 factor levels
    df['LotShape'] = df['LotShape'].map({'Reg': 'Reg', 'IR1': 'Reg', 'IR2': 'Irreg', 'IR3': 'Irreg'})

    # simplifying MSSubClass because we have the year built in another feature
    df['MSSubClass'] = df['MSSubClass'].map(lambda x: 
        "1_story"   if (x in (20, 30, 40, 120)) else(
        "1.5_story" if (x in (45, 50, 150)) else(
        "2_story"   if (x in (60, 70, 75, 160, 180, 190)) else(
        "split"     if (x in (80, 85)) else(
        "duplex"    if (x ==90) else(
        "other"))))))
    df['MSSubClass'] = df['MSSubClass'].astype("object")

    
    
    # deciding to drop a few features for various reasons
    vars_to_drop = [
        "LowQualFinSF", # hardly any variation
        "LandSlope", # not much variation
        "PoolArea", # binarized above
        "MiscVal", # not much variation
        "Utilities", # only 1 obs in training data different from regular
        #"KitchenAbvGr" # hardly any variation. But, Deva included in lm's so including it now.
        ]
    df.drop(columns=vars_to_drop, inplace=True) 

    # adding a remodeled feature
    df['Remodeled'] = (df.YearRemodAdd-df.YearBuilt) == 0

    # total inside area will be a sum of 1st and 2nd floor sq ft
    df['Total_Inside_Area'] = df['1stFlrSF'] + df['2ndFlrSF']
    df.drop(columns = ['1stFlrSF', '2ndFlrSF', 'GrLivArea'], inplace = True)

    # simplify the bathrooms variable
    df['Bathrooms'] = df.BsmtFullBath + 0.5*df.BsmtHalfBath + df.FullBath + 0.5*df.HalfBath
    df.drop(columns = ['BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath'], inplace = True)

    ### JARED EDITS
    # minimal transformations.
    
    # for some vars values are 0, since ln(0) = -inf, I have to recode values of 0 to 1
    # as ln(1) =0. 
    
    #for x in range(len(df.BsmtFinSF1)):
    #    if df['BsmtFinSF1'][x] ==0:
    #        df['BsmtFinSF1'][x] = 1
        
    #for x in range(len(df.MasVnrArea)):
    #    if df['MasVnrArea'][x] ==0:
    #        df['MasVnrArea'][x] = 1
    
    #for x in range(len(df.GarageArea)):
    #    if df['GarageArea'][x] ==0:
    #        df['GarageArea'][x] = 1
    
    for x in range(len(df.TotalBsmtSF)):
        if df['TotalBsmtSF'][x] ==0:
            df['TotalBsmtSF'][x] = 1
            
    #for x in range(len(df.WoodDeckSF)):
    #    if df['WoodDeckSF'][x] ==0:
    #        df['WoodDeckSF'][x] = 1
    
    df.Total_Inside_Area = np.log(df.Total_Inside_Area)
    df.TotalBsmtSF = np.log(df.TotalBsmtSF)
    #df.GarageArea = np.log(df.GarageArea)  
    #df.BsmtFinSF1 = np.log(df.BsmtFinSF1)
    df.LotArea = np.log(df.LotArea)
    #df.WoodDeckSF = np.log(df.WoodDeckSF)
    #df.MasVnrArea = np.log(df.MasVnrArea)

    
    ###
    
    
    ## Deva's Edit
    # Expensive Neighborhoods based on earlier EDA
    Expensive_neighborhoods = ['Somerst', 'Blmngtn', 'BrDale', 'NridgHt', 'StoneBr', 'MeadowV']
    df['Expensive_neighborhood'] = train['Neighborhood'].apply(lambda x: any([k in x for k in Expensive_neighborhoods]))
    ##
    
    # get log of sale price which will be our actual response variable
    if test_data:
        pass 
    else:
        df['LogSalePrice'] = np.log(df.SalePrice)
        
        
        

    return df

# %%
# run function on test and train
train = feature_eng(train)
test = feature_eng(test, test_data=True)
# Out:
# <ipython-input-30-bb4179e26d2f>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalBsmtSF'][x] = 1
# <ipython-input-30-bb4179e26d2f>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalBsmtSF'][x] = 1

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Linear Model

# %% [markdown]
# Function to prep data for a very baseline linear model

# %%
def lm_df_clean(df):

    lm_vars = ['LotArea', 'Street', 'Neighborhood', 'OverallQual', 'OverallCond', 'YearRemodAdd', 
              'BsmtCond', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'YrSold', 
              'MoSold', 'Remodeled', 'Total_Inside_Area', 'Bathrooms']

    df = pd.get_dummies(df[lm_vars], 
        columns = ['Street', 'Neighborhood', 'OverallQual', 'OverallCond', 'BsmtCond','KitchenQual'], 
        drop_first=True)
    
    return df

# %% [markdown]
# Get train/test data all ready

# %%
X_train = lm_df_clean(train)
X_test = lm_df_clean(test)
Y_train = train.SalePrice
Y_test = sample.SalePrice

# %% [markdown]
# Baseline linear model is very overfit

# %%
# Decent R2
from sklearn.linear_model import LinearRegression
lr_1 = LinearRegression(fit_intercept=True)
lr_1.fit(X_train,Y_train)

print("Fit on training data: {:.3f}".format(lr_1.score(X_train,Y_train)))
print("Fit on testing data: {:.3f}".format(lr_1.score(X_test ,Y_test)))
# Out:
# Fit on training data: 0.855
# Fit on testing data: -17.670

# %% [markdown]
# Same feature set with a baseline RandomForest is also overfit

# %%
dt = DecisionTreeRegressor(random_state = 0)
dt.fit(X_train, Y_train)

print("Fit on training data: {:.3f}".format(dt.score(X_train,Y_train)))
print("Fit on testing data: {:.3f}".format(dt.score(X_test ,Y_test)))
# Out:
# Fit on training data: 1.000
# Fit on testing data: -18.893

# %% [markdown]
# Basic linear model with single coefficient

# %%
#Simplest possible model - Chose variable with highest coefficient from initial correlation matrix

X_train_2 = train.drop(train.columns.difference(['OverallQual']), 1)
X_test_2 = test.drop(test.columns.difference(['OverallQual']), 1)
Y_train = train.SalePrice
Y_test = sample.SalePrice

lr_2 = LinearRegression(fit_intercept=True)
lr_2.fit(X_train_2,Y_train)

print("Fit on training data: {:.3f}".format(lr_2.score(X_train_2,Y_train)))
print("Fit on testing data: {:.3f}".format(lr_2.score(X_test_2 ,Y_test)))
# Out:
# Fit on training data: 0.626
# Fit on testing data: -14.882

# %% [markdown]
# ## Random forest with cross validation

# %%
# preprocess the data
train_dummies = pd.get_dummies(train)

# create the train and test splits
dev_train, dev_test = train_test_split(train_dummies, test_size=0.3, random_state=1)

# specify model
rf = RandomForestRegressor(bootstrap=True, max_features='auto')

# run grid search on range of values
grid = {
    "n_estimators": np.arange(100, 1001, 100),
    'max_depth': np.arange(10, 101, 5),
    'min_samples_split': [2, 5, 7],
}

# put our parameters into GridSearch
gscv = GridSearchCV(
    estimator = rf, 
    param_grid = grid, 
    n_jobs = -1, 
    cv = 3)

# run the search:
# this took 26 min to run. 
# re-run if you want
#results = gscv.fit(dev_train.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_train.LogSalePrice)

# check out the best parameters
#print(results.best_params_)
# {'max_depth': 25, 'min_samples_split': 2, 'n_estimators': 900}

# %%
for i in dev_train:
    for x in dev_train[i]:
        if x ==np.inf:
            print(i)
        elif x ==-np.inf:
            print(i)

# %%
# finally, run model on best parameters
rf_reg = RandomForestRegressor(
    n_estimators = 900,
    max_depth = 25,
    max_features = 'auto',
    min_samples_split = 2,  
    bootstrap = True, 
    )

# fit the model
rf_reg.fit(dev_train.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_train.LogSalePrice)

# evaluate it's performance on the unforseen testing set
yhat = rf_reg.predict(dev_test.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']))
resids = yhat - dev_test.LogSalePrice

# evaluate rmse and mae on the testing data
print("MAE: " + str(round(np.mean(resids.apply(lambda x: math.fabs(x))),4)))
print("RMSE: " + str(round(np.mean(resids**2)**.5,4)))
# MAE: 0.0999
# RMSE: 0.154
# Out:
# MAE: 0.1004
# RMSE: 0.1546

# %%
# score on train
rf_train_score = rf_reg.score(dev_train.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_train.LogSalePrice)
print("Score on train: {:.3f}".format(rf_train_score))

# score on test/dev
rf_dev_score = rf_reg.score(dev_test.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_test.LogSalePrice)
print("Score on test: {:.3f}".format(rf_dev_score))
# Out:
# Score on train: 0.981
# Score on test: 0.874

# %%
# variable importance plot
var_imp = pd.DataFrame({
    'feature': dev_train.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']).columns,
    'importance': rf_reg.feature_importances_
})
var_imp.sort_values("importance", ascending=False, inplace=True)

fig, ax = plt.subplots(figsize=(5, 7))
topn = 20
ax.barh(var_imp.head(topn).feature, var_imp.head(topn).importance)
ax.set_ylabel("Importance")
ax.set_xlabel("Feature")
ax.set_title("Feature Importance Plot: Top {}".format(topn))
ax.invert_yaxis()
print("")

# %% [markdown]
# ## Lasso Regression

# %%
for i in [0, 1.0e-10, 0.0001, 0.001, 0.01, 0.1, 0.5, 1.0, 2.0, 10.0]:

    # iterate over every vbalkue of alpha in the list, fit lasso regression
    model = Lasso(alpha = i)

    # copying Trevor's code, delete certain variables that don't matter
    model.fit(dev_train.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_train.LogSalePrice)

    # run 10-fold Cross validation to improve fit
    cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

    # calculate scores
    scores = cross_val_score(model, dev_train.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_train.LogSalePrice, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

    scores = absolute(scores)

    # calculate MAE, accuracy.
    print("Lasso alpha is equal to: ", i)
    print('Mean MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
    print('Accuracy:', model.score(dev_test.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_test.LogSalePrice))
# Out:
# <ipython-input-42-6bab5841d68a>:7: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model.fit(dev_train.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_train.LogSalePrice)
# C:\Users\drkul\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\drkul\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.6284304532263385, tolerance: 0.01497720138328087
#   model = cd_fast.enet_coordinate_descent(
# Lasso alpha is equal to:  0
# Mean MAE: 0.087 (0.012)
# Accuracy: 0.9097044141328873
# C:\Users\drkul\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.6284312004728374, tolerance: 0.01497720138328087
#   model = cd_fast.enet_coordinate_descent(
# Lasso alpha is equal to:  1e-10
# Mean MAE: 0.087 (0.012)
# Accuracy: 0.9097056109007458
# C:\Users\drkul\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19632484383418003, tolerance: 0.01497720138328087
#   model = cd_fast.enet_coordinate_descent(
# Lasso alpha is equal to:  0.0001
# Mean MAE: 0.081 (0.012)
# Accuracy: 0.9133501235787896
# Lasso alpha is equal to:  0.001
# Mean MAE: 0.083 (0.009)
# Accuracy: 0.8942009104972459
# Lasso alpha is equal to:  0.01
# Mean MAE: 0.105 (0.013)
# Accuracy: 0.859686813280689
# Lasso alpha is equal to:  0.1
# Mean MAE: 0.145 (0.018)
# Accuracy: 0.7585573083185597
# Lasso alpha is equal to:  0.5
# Mean MAE: 0.165 (0.018)
# Accuracy: 0.6973420545079846
# Lasso alpha is equal to:  1.0
# Mean MAE: 0.169 (0.018)
# Accuracy: 0.6766069116916817
# Lasso alpha is equal to:  2.0
# Mean MAE: 0.186 (0.018)
# Accuracy: 0.6123765128478742
# Lasso alpha is equal to:  10.0
# Mean MAE: 0.209 (0.020)
# Accuracy: 0.5164024107287357

# %%
# https://towardsdatascience.com/whats-the-difference-between-linear-regression-lasso-ridge-and-elasticnet-8f997c60cf29

# set asige log_sale_price in separate vectors
train_log_saleprice = dev_train.LogSalePrice
test_log_saleprice = dev_test.LogSalePrice

# drop unused variables
dev_train2 = dev_train.drop(columns = ["SalePrice", 'LogSalePrice', 'Id'])
dev_test2 = dev_test.drop(columns = ["SalePrice", 'LogSalePrice', 'Id'])

# standardize all values of all variables in data
scaler = StandardScaler()

scaler.fit(dev_train2)
dev_train2 = scaler.transform(dev_train2)

scaler.fit(dev_test2)
dev_test2 = scaler.transform(dev_test2)

# %%
for i in [0, 1.0e-10, 0.0001, 0.001, 0.01, 0.1, 0.5, 1.0, 2.0, 10.0]:
    
    # run and fit lasso regression again, this time with completely standardized data
    model = Lasso(alpha = i)

    model.fit(dev_train2, train_log_saleprice)

    # 10-fold cross validation to improve fit
    cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

    # calculate scores and accuracy
    scores = cross_val_score(model, dev_train2, train_log_saleprice, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

    scores = absolute(scores)

    print("Lasso alpha is equal to: ", i)
    print('Mean MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
    print('Accuracy:', model.score(dev_test2, test_log_saleprice))

# %%
for i in [0, 1.0e-10, 0.0001, 0.001, 0.01, 0.1, 0.5, 1.0, 2.0, 10.0, 25.0, 50.0, 75.0, 100.0]:

    # calculate ridge regression with completely standardized data
    model2 = Ridge(alpha = i)

    model2.fit(dev_train2, train_log_saleprice)

    # run 10-fold cross validation
    cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

    # calculate score
    scores = cross_val_score(model, dev_train2, train_log_saleprice, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

    scores = absolute(scores)

    # calculate MAE and Accuracy
    print("Lasso alpha is equal to: ", i)
    print('Mean MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
    print('Accuracy:', model2.score(dev_test2, test_log_saleprice))

# %%
for i in [0, 1.0e-10, 0.0001, 0.001, 0.01, 0.1, 0.5, 1.0, 2.0, 10.0]:

    # calculate Elastic Net with completely standardized data
    model3 = ElasticNet(alpha = i)

    model3.fit(dev_train2, train_log_saleprice)

    # 10-fold cross-validation to improve fit
    cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

    # calculate scores, MAE, and accuracy
    scores = cross_val_score(model, dev_train2, train_log_saleprice, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

    scores = absolute(scores)

    print("Lasso alpha is equal to: ", i)
    print('Mean MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
    print('Accuracy:', model3.score(dev_test2, test_log_saleprice))

# %%
for i in [0, 1.0e-10, 0.0001, 0.001, 0.01, 0.1, 0.5, 1.0, 2.0, 10.0]:

    # Ridge Regression with minimally transofrmed data
    model4 = Ridge(alpha = i)

    model4.fit(dev_train.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_train.LogSalePrice)

    # 10-fold cross-validation
    cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

    # calculate scores, MAE, and Accuracy
    scores = cross_val_score(model, dev_train.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_train.LogSalePrice, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

    scores = absolute(scores)

    print("Lasso alpha is equal to: ", i)
    print('Mean MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
    print('Accuracy:', model4.score(dev_test.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_test.LogSalePrice))

# %%
for i in [0, 1.0e-10, 0.0001, 0.001, 0.01, 0.1, 0.5, 1.0, 2.0, 10.0]:

    # calculate elastic net with minimally transformed data
    model5 = ElasticNet(alpha = i)

    model5.fit(dev_train.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_train.LogSalePrice)

    # run 10-fold cross-validation
    cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

    # calculate scores, MAE, and accuracy
    scores = cross_val_score(model, dev_train.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_train.LogSalePrice, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

    scores = absolute(scores)

    print("Lasso alpha is equal to: ", i)
    print('Mean MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
    print('Accuracy:', model5.score(dev_test.drop(columns = ["SalePrice", 'LogSalePrice', 'Id']), dev_test.LogSalePrice))

# %%
# Deva Neural Network attempt

# https://towardsdatascience.com/house-prices-prediction-using-deep-learning-dea265cc3154

import numpy as np
from keras.layers import Dense, Activation
from keras.models import Sequential
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Sleecting fewer features for NN
dev_train_NN = dev_train[['LotArea', 'OverallQual','Remodeled', 
                          'Total_Inside_Area', 'Bathrooms', 'Expensive_neighborhood'
                         ,'LogSalePrice']]
dev_test_NN = dev_test[['LotArea', 'OverallQual','Remodeled', 
                          'Total_Inside_Area', 'Bathrooms', 'Expensive_neighborhood'
                         ,'LogSalePrice']]

# Splitting the dataset into the Training set and Test set
X_train = dev_train_NN.drop(columns = ['LogSalePrice'])
X_test = dev_test_NN.drop(columns = ['LogSalePrice'])
y_train = dev_train_NN.LogSalePrice
y_test = dev_test_NN.LogSalePrice

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# having 6 neuron is based on the number of available features
model = Sequential()
model.add(Dense(6,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(1))

# Compiling the ANN
model.compile(optimizer='Adam',loss='mean_squared_error')

# Fitting the ANN to the Training set
model.fit(x=X_train,y=y_train,
          validation_data=(X_test,y_test),
          batch_size=128,epochs=400)
model.summary()

loss_df = pd.DataFrame(model.history.history)
loss_df.plot(figsize=(12,8))
# Out:
# Epoch 1/400
# 8/8 [==============================] - 1s 25ms/step - loss: 146.9230 - val_loss: 146.0020
# Epoch 2/400
# 8/8 [==============================] - 0s 7ms/step - loss: 145.1979 - val_loss: 144.2463
# Epoch 3/400
# 8/8 [==============================] - 0s 4ms/step - loss: 143.6132 - val_loss: 142.6010
# Epoch 4/400
# 8/8 [==============================] - 0s 5ms/step - loss: 142.1371 - val_loss: 141.0156
# Epoch 5/400
# 8/8 [==============================] - 0s 5ms/step - loss: 140.6751 - val_loss: 139.4321
# Epoch 6/400
# 8/8 [==============================] - 0s 5ms/step - loss: 139.1468 - val_loss: 137.8465
# Epoch 7/400
# 8/8 [==============================] - 0s 3ms/step - loss: 137.5555 - val_loss: 136.1740
# Epoch 8/400
# 8/8 [==============================] - 0s 7ms/step - loss: 135.8804 - val_loss: 134.4009
# Epoch 9/400
# 8/8 [==============================] - 0s 4ms/step - loss: 134.0622 - val_loss: 132.5179
# Epoch 10/400
# 8/8 [==============================] - 0s 5ms/step - loss: 132.1121 - val_loss: 130.5089
# Epoch 11/400
# 8/8 [==============================] - 0s 6ms/step - loss: 129.9643 - val_loss: 128.3730
# Epoch 12/400
# 8/8 [==============================] - 0s 7ms/step - loss: 127.6400 - val_loss: 125.9534
# Epoch 13/400
# 8/8 [==============================] - 0s 3ms/step - loss: 125.0841 - val_loss: 123.2620
# Epoch 14/400
# 8/8 [==============================] - 0s 6ms/step - loss: 122.2960 - val_loss: 120.2119
# Epoch 15/400
# 8/8 [==============================] - 0s 7ms/step - loss: 119.0849 - val_loss: 116.6539
# Epoch 16/400
# 8/8 [==============================] - 0s 3ms/step - loss: 115.3711 - val_loss: 112.4139
# Epoch 17/400
# 8/8 [==============================] - 0s 5ms/step - loss: 111.0026 - val_loss: 107.5587
# Epoch 18/400
# 8/8 [==============================] - 0s 6ms/step - loss: 106.0691 - val_loss: 102.1878
# Epoch 19/400
# 8/8 [==============================] - 0s 6ms/step - loss: 100.8056 - val_loss: 96.4099
# Epoch 20/400
# 8/8 [==============================] - 0s 4ms/step - loss: 95.0625 - val_loss: 90.3591
# Epoch 21/400
# 8/8 [==============================] - 0s 6ms/step - loss: 89.0808 - val_loss: 84.0912
# Epoch 22/400
# 8/8 [==============================] - 0s 6ms/step - loss: 82.9676 - val_loss: 77.6614
# Epoch 23/400
# 8/8 [==============================] - 0s 6ms/step - loss: 76.6552 - val_loss: 71.2651
# Epoch 24/400
# 8/8 [==============================] - 0s 6ms/step - loss: 70.4480 - val_loss: 65.0064
# Epoch 25/400
# 8/8 [==============================] - 0s 6ms/step - loss: 64.4059 - val_loss: 59.0650
# Epoch 26/400
# 8/8 [==============================] - 0s 7ms/step - loss: 58.6479 - val_loss: 53.6234
# Epoch 27/400
# 8/8 [==============================] - 0s 4ms/step - loss: 53.4363 - val_loss: 48.7101
# Epoch 28/400
# 8/8 [==============================] - 0s 4ms/step - loss: 48.6837 - val_loss: 44.3759
# Epoch 29/400
# 8/8 [==============================] - 0s 5ms/step - loss: 44.4570 - val_loss: 40.5183
# Epoch 30/400
# 8/8 [==============================] - 0s 4ms/step - loss: 40.6074 - val_loss: 37.1367
# Epoch 31/400
# 8/8 [==============================] - 0s 5ms/step - loss: 37.2358 - val_loss: 34.1793
# Epoch 32/400
# 8/8 [==============================] - 0s 4ms/step - loss: 34.3042 - val_loss: 31.5571
# Epoch 33/400
# 8/8 [==============================] - 0s 5ms/step - loss: 31.6898 - val_loss: 29.2085
# Epoch 34/400
# 8/8 [==============================] - 0s 5ms/step - loss: 29.3138 - val_loss: 27.0867
# Epoch 35/400
# 8/8 [==============================] - 0s 4ms/step - loss: 27.1465 - val_loss: 25.1532
# Epoch 36/400
# 8/8 [==============================] - 0s 5ms/step - loss: 25.2282 - val_loss: 23.4038
# Epoch 37/400
# 8/8 [==============================] - 0s 5ms/step - loss: 23.4751 - val_loss: 21.8913
# Epoch 38/400
# 8/8 [==============================] - 0s 5ms/step - loss: 21.9719 - val_loss: 20.4964
# Epoch 39/400
# 8/8 [==============================] - 0s 5ms/step - loss: 20.5915 - val_loss: 19.2318
# Epoch 40/400
# 8/8 [==============================] - 0s 5ms/step - loss: 19.3455 - val_loss: 18.0783
# Epoch 41/400
# 8/8 [==============================] - 0s 4ms/step - loss: 18.2131 - val_loss: 17.0411
# Epoch 42/400
# 8/8 [==============================] - 0s 3ms/step - loss: 17.1727 - val_loss: 16.0776
# Epoch 43/400
# 8/8 [==============================] - 0s 8ms/step - loss: 16.1895 - val_loss: 15.2003
# Epoch 44/400
# 8/8 [==============================] - 0s 4ms/step - loss: 15.2674 - val_loss: 14.3928
# Epoch 45/400
# 8/8 [==============================] - 0s 6ms/step - loss: 14.3991 - val_loss: 13.6041
# Epoch 46/400
# 8/8 [==============================] - 0s 5ms/step - loss: 13.5633 - val_loss: 12.8625
# Epoch 47/400
# 8/8 [==============================] - 0s 5ms/step - loss: 12.7822 - val_loss: 12.1431
# Epoch 48/400
# 8/8 [==============================] - 0s 4ms/step - loss: 12.0002 - val_loss: 11.4518
# Epoch 49/400
# 8/8 [==============================] - 0s 5ms/step - loss: 11.2484 - val_loss: 10.7641
# Epoch 50/400
# 8/8 [==============================] - 0s 6ms/step - loss: 10.5212 - val_loss: 10.0989
# Epoch 51/400
# 8/8 [==============================] - 0s 6ms/step - loss: 9.8128 - val_loss: 9.4452
# Epoch 52/400
# 8/8 [==============================] - 0s 4ms/step - loss: 9.1191 - val_loss: 8.8152
# Epoch 53/400
# 8/8 [==============================] - 0s 6ms/step - loss: 8.4640 - val_loss: 8.2125
# Epoch 54/400
# 8/8 [==============================] - 0s 5ms/step - loss: 7.8366 - val_loss: 7.6347
# Epoch 55/400
# 8/8 [==============================] - 0s 4ms/step - loss: 7.2510 - val_loss: 7.0908
# Epoch 56/400
# 8/8 [==============================] - 0s 4ms/step - loss: 6.6834 - val_loss: 6.5754
# Epoch 57/400
# 8/8 [==============================] - 0s 4ms/step - loss: 6.1495 - val_loss: 6.1099
# Epoch 58/400
# 8/8 [==============================] - 0s 4ms/step - loss: 5.6809 - val_loss: 5.6780
# Epoch 59/400
# 8/8 [==============================] - 0s 4ms/step - loss: 5.2505 - val_loss: 5.2930
# Epoch 60/400
# 8/8 [==============================] - 0s 4ms/step - loss: 4.8599 - val_loss: 4.9478
# Epoch 61/400
# 8/8 [==============================] - 0s 5ms/step - loss: 4.5084 - val_loss: 4.6178
# Epoch 62/400
# 8/8 [==============================] - 0s 5ms/step - loss: 4.2108 - val_loss: 4.3246
# Epoch 63/400
# 8/8 [==============================] - 0s 5ms/step - loss: 3.9273 - val_loss: 4.0624
# Epoch 64/400
# 8/8 [==============================] - 0s 5ms/step - loss: 3.6864 - val_loss: 3.8336
# Epoch 65/400
# 8/8 [==============================] - 0s 6ms/step - loss: 3.4687 - val_loss: 3.6203
# Epoch 66/400
# 8/8 [==============================] - 0s 4ms/step - loss: 3.2725 - val_loss: 3.4339
# Epoch 67/400
# 8/8 [==============================] - 0s 3ms/step - loss: 3.1040 - val_loss: 3.2573
# Epoch 68/400
# 8/8 [==============================] - 0s 2ms/step - loss: 2.9483 - val_loss: 3.1073
# Epoch 69/400
# 8/8 [==============================] - 0s 2ms/step - loss: 2.8077 - val_loss: 2.9602
# Epoch 70/400
# 8/8 [==============================] - 0s 2ms/step - loss: 2.6790 - val_loss: 2.8245
# Epoch 71/400
# 8/8 [==============================] - 0s 5ms/step - loss: 2.5589 - val_loss: 2.6951
# Epoch 72/400
# 8/8 [==============================] - 0s 4ms/step - loss: 2.4521 - val_loss: 2.5745
# Epoch 73/400
# 8/8 [==============================] - 0s 5ms/step - loss: 2.3474 - val_loss: 2.4614
# Epoch 74/400
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2534 - val_loss: 2.3568
# Epoch 75/400
# 8/8 [==============================] - 0s 4ms/step - loss: 2.1649 - val_loss: 2.2598
# Epoch 76/400
# 8/8 [==============================] - 0s 4ms/step - loss: 2.0763 - val_loss: 2.1667
# Epoch 77/400
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0004 - val_loss: 2.0827
# Epoch 78/400
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9243 - val_loss: 1.9996
# Epoch 79/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.8521 - val_loss: 1.9219
# Epoch 80/400
# 8/8 [==============================] - 0s 6ms/step - loss: 1.7887 - val_loss: 1.8502
# Epoch 81/400
# 8/8 [==============================] - 0s 8ms/step - loss: 1.7252 - val_loss: 1.7825
# Epoch 82/400
# 8/8 [==============================] - 0s 5ms/step - loss: 1.6670 - val_loss: 1.7141
# Epoch 83/400
# 8/8 [==============================] - 0s 5ms/step - loss: 1.6121 - val_loss: 1.6504
# Epoch 84/400
# 8/8 [==============================] - 0s 5ms/step - loss: 1.5552 - val_loss: 1.5941
# Epoch 85/400
# 8/8 [==============================] - 0s 6ms/step - loss: 1.5043 - val_loss: 1.5373
# Epoch 86/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.4568 - val_loss: 1.4857
# Epoch 87/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.4090 - val_loss: 1.4392
# Epoch 88/400
# 8/8 [==============================] - 0s 5ms/step - loss: 1.3659 - val_loss: 1.3861
# Epoch 89/400
# 8/8 [==============================] - 0s 5ms/step - loss: 1.3207 - val_loss: 1.3389
# Epoch 90/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.2816 - val_loss: 1.2950
# Epoch 91/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.2457 - val_loss: 1.2546
# Epoch 92/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.2038 - val_loss: 1.2170
# Epoch 93/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.1678 - val_loss: 1.1781
# Epoch 94/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.1310 - val_loss: 1.1410
# Epoch 95/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0984 - val_loss: 1.1041
# Epoch 96/400
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0674 - val_loss: 1.0722
# Epoch 97/400
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0344 - val_loss: 1.0408
# Epoch 98/400
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0060 - val_loss: 1.0099
# Epoch 99/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9770 - val_loss: 0.9784
# Epoch 100/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.9508 - val_loss: 0.9495
# Epoch 101/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.9224 - val_loss: 0.9229
# Epoch 102/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8985 - val_loss: 0.8947
# Epoch 103/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.8780 - val_loss: 0.8695
# Epoch 104/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8476 - val_loss: 0.8448
# Epoch 105/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.8250 - val_loss: 0.8221
# Epoch 106/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8023 - val_loss: 0.7991
# Epoch 107/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.7812 - val_loss: 0.7761
# Epoch 108/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7621 - val_loss: 0.7542
# Epoch 109/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.7391 - val_loss: 0.7324
# Epoch 110/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.7200 - val_loss: 0.7114
# Epoch 111/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.7010 - val_loss: 0.6925
# Epoch 112/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6824 - val_loss: 0.6730
# Epoch 113/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6647 - val_loss: 0.6540
# Epoch 114/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6481 - val_loss: 0.6383
# Epoch 115/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6312 - val_loss: 0.6214
# Epoch 116/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6151 - val_loss: 0.6057
# Epoch 117/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6026 - val_loss: 0.5915
# Epoch 118/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5855 - val_loss: 0.5753
# Epoch 119/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5707 - val_loss: 0.5597
# Epoch 120/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5569 - val_loss: 0.5441
# Epoch 121/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5446 - val_loss: 0.5301
# Epoch 122/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5312 - val_loss: 0.5177
# Epoch 123/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5184 - val_loss: 0.5056
# Epoch 124/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5070 - val_loss: 0.4935
# Epoch 125/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4945 - val_loss: 0.4827
# Epoch 126/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4828 - val_loss: 0.4689
# Epoch 127/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4710 - val_loss: 0.4570
# Epoch 128/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4597 - val_loss: 0.4476
# Epoch 129/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4495 - val_loss: 0.4375
# Epoch 130/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4384 - val_loss: 0.4267
# Epoch 131/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4280 - val_loss: 0.4161
# Epoch 132/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4181 - val_loss: 0.4074
# Epoch 133/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4085 - val_loss: 0.3962
# Epoch 134/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3992 - val_loss: 0.3864
# Epoch 135/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3895 - val_loss: 0.3791
# Epoch 136/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3806 - val_loss: 0.3697
# Epoch 137/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3716 - val_loss: 0.3628
# Epoch 138/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3634 - val_loss: 0.3532
# Epoch 139/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3549 - val_loss: 0.3450
# Epoch 140/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3485 - val_loss: 0.3390
# Epoch 141/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3386 - val_loss: 0.3315
# Epoch 142/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3311 - val_loss: 0.3241
# Epoch 143/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3247 - val_loss: 0.3150
# Epoch 144/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3170 - val_loss: 0.3086
# Epoch 145/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3106 - val_loss: 0.3037
# Epoch 146/400
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3041 - val_loss: 0.2986
# Epoch 147/400
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2969 - val_loss: 0.2913
# Epoch 148/400
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2913 - val_loss: 0.2839
# Epoch 149/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2844 - val_loss: 0.2778
# Epoch 150/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2784 - val_loss: 0.2719
# Epoch 151/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2726 - val_loss: 0.2671
# Epoch 152/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2672 - val_loss: 0.2617
# Epoch 153/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2616 - val_loss: 0.2577
# Epoch 154/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2569 - val_loss: 0.2520
# Epoch 155/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2520 - val_loss: 0.2458
# Epoch 156/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2475 - val_loss: 0.2410
# Epoch 157/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2413 - val_loss: 0.2364
# Epoch 158/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2370 - val_loss: 0.2313
# Epoch 159/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2322 - val_loss: 0.2274
# Epoch 160/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2279 - val_loss: 0.2241
# Epoch 161/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2237 - val_loss: 0.2189
# Epoch 162/400
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2198 - val_loss: 0.2149
# Epoch 163/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2152 - val_loss: 0.2107
# Epoch 164/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2113 - val_loss: 0.2065
# Epoch 165/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2086 - val_loss: 0.2032
# Epoch 166/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2035 - val_loss: 0.1993
# Epoch 167/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2006 - val_loss: 0.1955
# Epoch 168/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1967 - val_loss: 0.1931
# Epoch 169/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1940 - val_loss: 0.1897
# Epoch 170/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1899 - val_loss: 0.1864
# Epoch 171/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1874 - val_loss: 0.1827
# Epoch 172/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1841 - val_loss: 0.1808
# Epoch 173/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1811 - val_loss: 0.1769
# Epoch 174/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1780 - val_loss: 0.1746
# Epoch 175/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1747 - val_loss: 0.1714
# Epoch 176/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1723 - val_loss: 0.1679
# Epoch 177/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1692 - val_loss: 0.1654
# Epoch 178/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1664 - val_loss: 0.1633
# Epoch 179/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1634 - val_loss: 0.1613
# Epoch 180/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1608 - val_loss: 0.1587
# Epoch 181/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1585 - val_loss: 0.1568
# Epoch 182/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1565 - val_loss: 0.1528
# Epoch 183/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1536 - val_loss: 0.1521
# Epoch 184/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1512 - val_loss: 0.1504
# Epoch 185/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1487 - val_loss: 0.1473
# Epoch 186/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1464 - val_loss: 0.1460
# Epoch 187/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1442 - val_loss: 0.1437
# Epoch 188/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1420 - val_loss: 0.1410
# Epoch 189/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1398 - val_loss: 0.1387
# Epoch 190/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1384 - val_loss: 0.1376
# Epoch 191/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1362 - val_loss: 0.1353
# Epoch 192/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1341 - val_loss: 0.1344
# Epoch 193/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1321 - val_loss: 0.1332
# Epoch 194/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1305 - val_loss: 0.1311
# Epoch 195/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1288 - val_loss: 0.1284
# Epoch 196/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1272 - val_loss: 0.1271
# Epoch 197/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1252 - val_loss: 0.1258
# Epoch 198/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1243 - val_loss: 0.1239
# Epoch 199/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1219 - val_loss: 0.1228
# Epoch 200/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1209 - val_loss: 0.1212
# Epoch 201/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1190 - val_loss: 0.1207
# Epoch 202/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1178 - val_loss: 0.1200
# Epoch 203/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1165 - val_loss: 0.1179
# Epoch 204/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1150 - val_loss: 0.1164
# Epoch 205/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1136 - val_loss: 0.1147
# Epoch 206/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1127 - val_loss: 0.1132
# Epoch 207/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1110 - val_loss: 0.1124
# Epoch 208/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1099 - val_loss: 0.1112
# Epoch 209/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1087 - val_loss: 0.1105
# Epoch 210/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1074 - val_loss: 0.1096
# Epoch 211/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1064 - val_loss: 0.1084
# Epoch 212/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1056 - val_loss: 0.1086
# Epoch 213/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1040 - val_loss: 0.1057
# Epoch 214/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1029 - val_loss: 0.1046
# Epoch 215/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1017 - val_loss: 0.1040
# Epoch 216/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1008 - val_loss: 0.1039
# Epoch 217/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0998 - val_loss: 0.1024
# Epoch 218/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0986 - val_loss: 0.1019
# Epoch 219/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0977 - val_loss: 0.1014
# Epoch 220/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0967 - val_loss: 0.0995
# Epoch 221/400
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0958 - val_loss: 0.0986
# Epoch 222/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0949 - val_loss: 0.0974
# Epoch 223/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0940 - val_loss: 0.0978
# Epoch 224/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0933 - val_loss: 0.0970
# Epoch 225/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0925 - val_loss: 0.0948
# Epoch 226/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0915 - val_loss: 0.0951
# Epoch 227/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0906 - val_loss: 0.0935
# Epoch 228/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0897 - val_loss: 0.0934
# Epoch 229/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0892 - val_loss: 0.0929
# Epoch 230/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0881 - val_loss: 0.0918
# Epoch 231/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0874 - val_loss: 0.0911
# Epoch 232/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0868 - val_loss: 0.0905
# Epoch 233/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0864 - val_loss: 0.0888
# Epoch 234/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0856 - val_loss: 0.0905
# Epoch 235/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0845 - val_loss: 0.0882
# Epoch 236/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0838 - val_loss: 0.0871
# Epoch 237/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0831 - val_loss: 0.0864
# Epoch 238/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0825 - val_loss: 0.0870
# Epoch 239/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0819 - val_loss: 0.0864
# Epoch 240/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0814 - val_loss: 0.0848
# Epoch 241/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0805 - val_loss: 0.0844
# Epoch 242/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0800 - val_loss: 0.0846
# Epoch 243/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0793 - val_loss: 0.0839
# Epoch 244/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0792 - val_loss: 0.0814
# Epoch 245/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0778 - val_loss: 0.0825
# Epoch 246/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0772 - val_loss: 0.0819
# Epoch 247/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0772 - val_loss: 0.0814
# Epoch 248/400
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0761 - val_loss: 0.0813
# Epoch 249/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0757 - val_loss: 0.0797
# Epoch 250/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0749 - val_loss: 0.0794
# Epoch 251/400
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0744 - val_loss: 0.0794
# Epoch 252/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0738 - val_loss: 0.0788
# Epoch 253/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0776
# Epoch 254/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0726 - val_loss: 0.0776
# Epoch 255/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0721 - val_loss: 0.0768
# Epoch 256/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0715 - val_loss: 0.0764
# Epoch 257/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0712 - val_loss: 0.0760
# Epoch 258/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0704 - val_loss: 0.0753
# Epoch 259/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0701 - val_loss: 0.0747
# Epoch 260/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0696 - val_loss: 0.0745
# Epoch 261/400
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0690 - val_loss: 0.0745
# Epoch 262/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0684 - val_loss: 0.0738
# Epoch 263/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0679 - val_loss: 0.0727
# Epoch 264/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0680 - val_loss: 0.0726
# Epoch 265/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0669 - val_loss: 0.0720
# Epoch 266/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0667 - val_loss: 0.0716
# Epoch 267/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0659 - val_loss: 0.0712
# Epoch 268/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0655 - val_loss: 0.0704
# Epoch 269/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0651 - val_loss: 0.0708
# Epoch 270/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0646 - val_loss: 0.0701
# Epoch 271/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0642 - val_loss: 0.0698
# Epoch 272/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0638 - val_loss: 0.0697
# Epoch 273/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0635 - val_loss: 0.0684
# Epoch 274/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0633 - val_loss: 0.0687
# Epoch 275/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0626 - val_loss: 0.0675
# Epoch 276/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0622 - val_loss: 0.0680
# Epoch 277/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0617 - val_loss: 0.0670
# Epoch 278/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0616 - val_loss: 0.0663
# Epoch 279/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0611 - val_loss: 0.0675
# Epoch 280/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0602 - val_loss: 0.0661
# Epoch 281/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0600 - val_loss: 0.0657
# Epoch 282/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0594 - val_loss: 0.0652
# Epoch 283/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0594 - val_loss: 0.0651
# Epoch 284/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0587 - val_loss: 0.0647
# Epoch 285/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0584 - val_loss: 0.0639
# Epoch 286/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0586 - val_loss: 0.0635
# Epoch 287/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0585 - val_loss: 0.0635
# Epoch 288/400
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0570 - val_loss: 0.0630
# Epoch 289/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0568 - val_loss: 0.0631
# Epoch 290/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0563 - val_loss: 0.0619
# Epoch 291/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0560 - val_loss: 0.0621
# Epoch 292/400
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0555 - val_loss: 0.0614
# Epoch 293/400
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0552 - val_loss: 0.0609
# Epoch 294/400
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0549 - val_loss: 0.0602
# Epoch 295/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0545 - val_loss: 0.0606
# Epoch 296/400
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0540 - val_loss: 0.0600
# Epoch 297/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0536 - val_loss: 0.0593
# Epoch 298/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0534 - val_loss: 0.0589
# Epoch 299/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0531 - val_loss: 0.0587
# Epoch 300/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0525 - val_loss: 0.0583
# Epoch 301/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0528 - val_loss: 0.0587
# Epoch 302/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0518 - val_loss: 0.0577
# Epoch 303/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0515 - val_loss: 0.0573
# Epoch 304/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0514 - val_loss: 0.0571
# Epoch 305/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0508 - val_loss: 0.0564
# Epoch 306/400
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0505 - val_loss: 0.0560
# Epoch 307/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0501 - val_loss: 0.0561
# Epoch 308/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0497 - val_loss: 0.0557
# Epoch 309/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0496 - val_loss: 0.0549
# Epoch 310/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0491 - val_loss: 0.0544
# Epoch 311/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0487 - val_loss: 0.0545
# Epoch 312/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0484 - val_loss: 0.0544
# Epoch 313/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0479 - val_loss: 0.0537
# Epoch 314/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0476 - val_loss: 0.0534
# Epoch 315/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0475 - val_loss: 0.0526
# Epoch 316/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0469 - val_loss: 0.0526
# Epoch 317/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0467 - val_loss: 0.0525
# Epoch 318/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0463 - val_loss: 0.0524
# Epoch 319/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0461 - val_loss: 0.0521
# Epoch 320/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0458 - val_loss: 0.0520
# Epoch 321/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0455 - val_loss: 0.0508
# Epoch 322/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0450 - val_loss: 0.0510
# Epoch 323/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0448 - val_loss: 0.0507
# Epoch 324/400
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0444 - val_loss: 0.0498
# Epoch 325/400
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0442 - val_loss: 0.0495
# Epoch 326/400
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0439 - val_loss: 0.0499
# Epoch 327/400
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0437 - val_loss: 0.0496
# Epoch 328/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0434 - val_loss: 0.0492
# Epoch 329/400
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0431 - val_loss: 0.0486
# Epoch 330/400
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0429 - val_loss: 0.0481
# Epoch 331/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0428 - val_loss: 0.0482
# Epoch 332/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0426 - val_loss: 0.0482
# Epoch 333/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0426 - val_loss: 0.0472
# Epoch 334/400
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0421 - val_loss: 0.0481
# Epoch 335/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0420 - val_loss: 0.0470
# Epoch 336/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0417 - val_loss: 0.0474
# Epoch 337/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0418 - val_loss: 0.0464
# Epoch 338/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0412 - val_loss: 0.0458
# Epoch 339/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0411 - val_loss: 0.0463
# Epoch 340/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0410 - val_loss: 0.0463
# Epoch 341/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0408 - val_loss: 0.0458
# Epoch 342/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0403 - val_loss: 0.0453
# Epoch 343/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0403 - val_loss: 0.0448
# Epoch 344/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0402 - val_loss: 0.0454
# Epoch 345/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0400 - val_loss: 0.0446
# Epoch 346/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0399 - val_loss: 0.0447
# Epoch 347/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0396 - val_loss: 0.0450
# Epoch 348/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0393 - val_loss: 0.0437
# Epoch 349/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0392 - val_loss: 0.0440
# Epoch 350/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0390 - val_loss: 0.0440
# Epoch 351/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0390 - val_loss: 0.0437
# Epoch 352/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0386 - val_loss: 0.0438
# Epoch 353/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0387 - val_loss: 0.0428
# Epoch 354/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0384 - val_loss: 0.0425
# Epoch 355/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0384 - val_loss: 0.0430
# Epoch 356/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0384 - val_loss: 0.0431
# Epoch 357/400
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0381 - val_loss: 0.0423
# Epoch 358/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0378 - val_loss: 0.0418
# Epoch 359/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0382 - val_loss: 0.0431
# Epoch 360/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0373 - val_loss: 0.0426
# Epoch 361/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0369 - val_loss: 0.0418
# Epoch 362/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0371 - val_loss: 0.0410
# Epoch 363/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0368 - val_loss: 0.0419
# Epoch 364/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0366 - val_loss: 0.0414
# Epoch 365/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0364 - val_loss: 0.0418
# Epoch 366/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0362 - val_loss: 0.0415
# Epoch 367/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0363 - val_loss: 0.0413
# Epoch 368/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0358 - val_loss: 0.0406
# Epoch 369/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0354 - val_loss: 0.0404
# Epoch 370/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0355 - val_loss: 0.0411
# Epoch 371/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0351 - val_loss: 0.0405
# Epoch 372/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0350 - val_loss: 0.0403
# Epoch 373/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0347 - val_loss: 0.0398
# Epoch 374/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0346 - val_loss: 0.0397
# Epoch 375/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0346 - val_loss: 0.0396
# Epoch 376/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0345 - val_loss: 0.0396
# Epoch 377/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0346 - val_loss: 0.0399
# Epoch 378/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0343 - val_loss: 0.0396
# Epoch 379/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0338 - val_loss: 0.0387
# Epoch 380/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0337 - val_loss: 0.0387
# Epoch 381/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0335 - val_loss: 0.0392
# Epoch 382/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0334 - val_loss: 0.0393
# Epoch 383/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0333 - val_loss: 0.0389
# Epoch 384/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0333 - val_loss: 0.0380
# Epoch 385/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0330 - val_loss: 0.0381
# Epoch 386/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0331 - val_loss: 0.0387
# Epoch 387/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0329 - val_loss: 0.0384
# Epoch 388/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0330 - val_loss: 0.0378
# Epoch 389/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0328 - val_loss: 0.0380
# Epoch 390/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0326 - val_loss: 0.0376
# Epoch 391/400
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0323 - val_loss: 0.0375
# Epoch 392/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0327 - val_loss: 0.0369
# Epoch 393/400
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0322 - val_loss: 0.0374
# Epoch 394/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0321 - val_loss: 0.0377
# Epoch 395/400
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0320 - val_loss: 0.0374
# Epoch 396/400
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0320 - val_loss: 0.0366
# Epoch 397/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0361
# Epoch 398/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0369
# Epoch 399/400
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0369
# Epoch 400/400
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0316 - val_loss: 0.0365
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 6)                 42
#
#  dense_18 (Dense)            (None, 6)                 42
#
#  dense_19 (Dense)            (None, 6)                 42
#
#  dense_20 (Dense)            (None, 6)                 42
#
#  dense_21 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 175
# Trainable params: 175
# Non-trainable params: 0
# _________________________________________________________________
# <AxesSubplot:>

# %%
# Evaluate the NN

y_pred = model.predict(X_test)
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))  
print('MSE:', metrics.mean_squared_error(y_test, y_pred))  
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('VarScore:',metrics.explained_variance_score(y_test,y_pred))
# Visualizing Our predictions
fig = plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred)
# Perfect predictions
plt.plot(y_test,y_test,'r')
# Out:
# MAE: 0.1392450764668557
# MSE: 0.03646901825025569
# RMSE: 0.19096863158711613
# VarScore: 0.807032524900153
